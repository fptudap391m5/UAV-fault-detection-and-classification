# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Siêu dữ liệu trích xuất từ tên tệp tin (Filename Metadata Extraction)**
#
# ### Bảng đối chiếu tên cột dữ liệu đề xuất thêm
#
# | Thành phần trích xuất từ tên file | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | Tên phương tiện / Platform | `aircraft_type` | Tên của UAV thực hiện chuyến bay (ví dụ: `carbonZ` đại diện cho dòng máy bay cánh bằng CarbonZ T-28). |
# | Mã phiên bay / Sequence ID | `flight_sequence_id` | Chuỗi thời gian định danh duy nhất cho chuyến bay đó (ví dụ: `2018-07-18-12-10-11`). Cột này dùng để nhóm (Group) dữ liệu theo từng chuyến bay khi gộp các file lại với nhau. |
# | Phân loại lỗi của chuyến bay | `sequence_fault_type` | Nhãn lỗi chung của chuyến bay trích xuất từ tên tệp (ví dụ: `no_ground_truth` là bay thường, hoặc các nhãn lỗi phần cứng cụ thể khác tùy chuyến bay). |
# | Chỉ thị chuyến bay lỗi | `is_faulty_sequence` | Biến nhị phân xác định chuyến bay này có sự cố hay không (`0` nếu chứa cụm từ `no_ground_truth` - tức bay bình thường, `1` nếu là chuyến bay có cấy lỗi để huấn luyện mô hình phát hiện lỗi). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Trạng thái sự cố động cơ (Engine Failure Status) - `failure_status-engines.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận sự kiện (nanoseconds). |
# | `field.data` | `engine_failure_status` | Trạng thái lỗi mất động cơ. `0` (hoặc `false`): hoạt động bình thường; `1` (hoặc `true`): xảy ra lỗi mất hoàn toàn điện động cơ. |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Trạng thái sự cố cánh liệng (Aileron Failure Status) - `failure_status-aileron.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận sự kiện (nanoseconds). |
# | `field.data` | `aileron_failure_status` | Trạng thái lỗi cánh liệng kẹt ở góc 0:<br>- `0`: Hoạt động bình thường.<br>- `1`: Kẹt cánh liệng bên phải (Right).<br>- `2`: Kẹt cánh liệng bên trái (Left).<br>- `3`: Kẹt cả hai cánh liệng (Both). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Trạng thái sự cố bánh lái hướng (Rudder Failure Status) - `failure_status-rudder.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận sự kiện (nanoseconds). |
# | `field.data` | `rudder_failure_status` | Trạng thái lỗi bánh lái hướng:<br>- `0`: Hoạt động bình thường.<br>- `1`: Bánh lái kẹt ở vị trí 0.<br>- `2`: Bánh lái kẹt cứng hết cỡ về bên trái (Left hardover).<br>- `3`: Bánh lái kẹt cứng hết cỡ về bên phải (Right hardover). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Trạng thái sự cố cánh lái độ cao (Elevator Failure Status) - `failure_status-elevator.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận sự kiện (nanoseconds). |
# | `field.data` | `elevator_failure_status` | Trạng thái lỗi cánh lái độ cao:<br>- `0`: Hoạt động bình thường.<br>- `1`: Cánh lái kẹt ở vị trí 0.<br>- `2`: Cánh lái kẹt cứng hướng đi xuống (Stuck all the way down). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Điều hướng và giám sát góc cuộn (Roll Navigation & Measurement) - `mavros-nav_info-roll.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin. |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu (ví dụ: NED). |
# | `field.commanded` | `commanded_roll` | Góc roll yêu cầu từ bộ điều khiển (độ). |
# | `field.measured` | `measured_roll` | Góc roll đo được thực tế từ cảm biến (độ). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Điều hướng và giám sát góc cuộn (Roll Navigation & Measurement) - `mavros-nav_info-pitch.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin. |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu (ví dụ: NED). |
# | `field.commanded` | `commanded_pitch` | Góc pitch yêu cầu từ bộ điều khiển (độ). |
# | `field.measured` | `measured_pitch` | Góc pitch đo được thực tế từ cảm biến (độ). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Điều hướng và giám sát góc cuộn (Roll Navigation & Measurement) - `mavros-nav_info-yaw.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin. |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu (ví dụ: NED). |
# | `field.commanded` | `commanded_yaw` | Góc yaw yêu cầu từ bộ điều khiển (độ). |
# | `field.measured` | `measured_yaw` | Góc yaw đo được thực tế từ cảm biến (độ). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Điều hướng và giám sát góc cuộn (Roll Navigation & Measurement) - `mavros-nav_info-airspeed`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin. |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu (ví dụ: NED). |
# | `field.commanded` | `commanded_airspeed` | Tốc độ gió yêu cầu từ bộ điều khiển (m/s) |
# | `field.measured` | `measured_airspeed` | Tốc độ gió đo được thực tế từ cảm biến (m/s) |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Giám sát và điều hướng vận tốc di chuyển 3 trục (Velocity Tracking & Navigation) - `mavros-nav_info-velocity.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: NED - có thể xuất hiện dưới tên `frame_id`). |
# | `field.coordinate_frame` | `coordinate_frame` | Mã tiêu chuẩn MAVLink cho hệ quy chiếu tính vận tốc (ví dụ: giá trị 5). |
# | `field.des_x` | `desired_velocity_x` | Vận tốc mong muốn theo trục X (hướng Bắc/Nam) (m/s). |
# | `field.des_y` | `desired_velocity_y` | Vận tốc mong muốn theo trục Y (hướng Đông/Tây) (m/s). |
# | `field.des_z` | `desired_velocity_z` | Vận tốc mong muốn theo trục Z (hướng Lên/Xuống) (m/s). |
# | `field.meas_x` | `measured_velocity_x` | Vận tốc thực tế đo được theo trục X (hướng Bắc/Nam) (m/s). |
# | `field.meas_y` | `measured_velocity_y` | Vận tốc thực tế đo được theo trục Y (hướng Đông/Tây) (m/s). |
# | `field.meas_z` | `measured_velocity_z` | Vận tốc thực tế đo được theo trục Z (hướng Lên/Xuống) (m/s). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Giám sát sai số điều hướng hành trình (Navigation Errors Monitoring) - `mavros-nav_info-errors.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: NED - có thể xuất hiện dưới tên `frame_id`). |
# | `field.alt_error` | `altitude_error` | Sai số độ cao (mét). |
# | `field.aspd_error` | `airspeed_error` | Sai số tốc độ gió (thường đo bằng cm/s trong MAVLink thô, cần chia cho 100 để đưa về m/s). |
# | `field.xtrack_error` | `crosstrack_error` | Sai số lệch làn so với đường hành trình mục tiêu (mét). |
# | `field.wp_dist` | `waypoint_distance` | Khoảng cách địa lý còn lại tới điểm Waypoint tiếp theo (mét). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường tư thế góc xoay thực tế tần số cao (High-Frequency Roll-Pitch-Yaw Measurement) - `mavctrl-rpy.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.x` | `measured_roll_rad` | Góc roll thực tế đo được từ cảm biến (radians). |
# | `field.y` | `measured_pitch_rad` | Góc pitch thực tế đo được từ cảm biến (radians - hệ tọa độ ROS). |
# | `field.z` | `measured_yaw_rad` | Góc yaw thực tế (hướng mũi bay) đo được từ cảm biến (radians). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường sai lệch quỹ đạo 3D tần số cao (High-Frequency 3D Path Deviation Measurement) - `mavctrl-path_dev.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.x` | `along_track_deviation` | Sai lệch dọc theo quỹ đạo bay (mét). |
# | `field.y` | `cross_track_deviation` | Sai lệch ngang (trái/phải) so với quỹ đạo bay (mét). |
# | `field.z` | `vertical_track_deviation` | Sai lệch đứng (cao độ) so với quỹ đạo bay (mét). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường vị trí và tư thế 3D cục bộ (Local 3D Position & Orientation Measurement) - `mavros-local_position-pose.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin. |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: map). |
# | `field.pose.position.x` | `local_position_x` | Vị trí thực tế theo trục X (hướng Đông/Tây) so với điểm Home (mét). |
# | `field.pose.position.y` | `local_position_y` | Vị trí thực tế theo trục Y (hướng Bắc/Nam) so với điểm Home (mét). |
# | `field.pose.position.z` | `local_position_z` | Vị trí thực tế theo trục Z (độ cao so với mặt đất) so với điểm Home (mét). |
# | `field.pose.orientation.x`| `orientation_qx` | Thành phần X của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.pose.orientation.y`| `orientation_qy` | Thành phần Y của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.pose.orientation.z`| `orientation_qz` | Thành phần Z của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.pose.orientation.w`| `orientation_qw` | Thành phần W của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Định vị tích hợp và đo lường động lực học bay (Odometry & Flight Dynamics Measurement) - `mavros-local_position-odom.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin. |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds). |
# | `field.header.frame_id` | `frame_id` | Hệ quy chiếu mốc cố định trên mặt đất (ví dụ: map). |
# | `field.child_frame_id` | `child_frame_id` | Hệ quy chiếu gắn trên thân máy bay (ví dụ: base_link). |
# | `field.pose.pose.position.x` | `odom_position_x` | Vị trí theo trục X (hướng Đông/Tây) so với điểm Home (mét). |
# | `field.pose.pose.position.y` | `odom_position_y` | Vị trí theo trục Y (hướng Bắc/Nam) so với điểm Home (mét). |
# | `field.pose.pose.position.z` | `odom_position_z` | Vị trí theo trục Z (độ cao so với mặt đất) so với điểm Home (mét). |
# | `field.pose.pose.orientation.x` | `odom_orientation_qx` | Thành phần X của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.pose.pose.orientation.y` | `odom_orientation_qy` | Thành phần Y của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.pose.pose.orientation.z` | `odom_orientation_qz` | Thành phần Z của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.pose.pose.orientation.w` | `odom_orientation_qw` | Thành phần W của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.twist.twist.linear.x` | `body_linear_velocity_x` | Vận tốc tuyến tính dọc thân máy bay tiến về phía trước (m/s). |
# | `field.twist.twist.linear.y` | `body_linear_velocity_y` | Vận tốc tuyến tính trượt ngang sang trái/phải thân máy bay (m/s). |
# | `field.twist.twist.linear.z` | `body_linear_velocity_z` | Vận tốc tuyến tính nâng/hạ thẳng đứng so với bụng máy bay (m/s). |
# | `field.twist.twist.angular.x` | `body_angular_velocity_x` | Tốc độ quay quanh trục dọc thân máy bay (Roll rate) (rad/s). |
# | `field.twist.twist.angular.y` | `body_angular_velocity_y` | Tốc độ quay quanh trục ngang thân máy bay (Pitch rate) (rad/s). |
# | `field.twist.twist.angular.z` | `body_angular_velocity_z` | Tốc độ quay quanh trục đứng thân máy bay (Yaw rate) (rad/s). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường vận tốc tuyến tính và vận tốc góc cục bộ (Local Linear & Angular Velocity Measurement) - `mavros-local_position-velocity.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: map - có thể xuất hiện dưới tên `frame_id`). |
# | `field.twist.linear.x` | `local_linear_velocity_x` | Vận tốc tuyến tính thực tế theo hướng Đông/Tây (hệ ENU) (m/s). |
# | `field.twist.linear.y` | `local_linear_velocity_y` | Vận tốc tuyến tính thực tế theo hướng Bắc/Nam (hệ ENU) (m/s). |
# | `field.twist.linear.z` | `local_linear_velocity_z` | Vận tốc tuyến tính thực tế theo hướng Lên/Xuống (hệ ENU) (m/s). |
# | `field.twist.angular.x` | `body_angular_velocity_x` | Tốc độ quay quanh trục dọc thân máy bay (Roll rate) (rad/s). *Trùng khớp với giá trị trong file odom.* |
# | `field.twist.angular.y` | `body_angular_velocity_y` | Tốc độ quay quanh trục ngang thân máy bay (Pitch rate) (rad/s). *Trùng khớp với giá trị trong file odom.* |
# | `field.twist.angular.z` | `body_angular_velocity_z` | Tốc độ quay quanh trục đứng thân máy bay (Yaw rate) (rad/s). *Trùng khớp với giá trị trong file odom.* |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Định vị vệ tinh toàn cầu GPS thô (Raw GPS Global Positioning) - `mavros-global_position-global.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: base_link - có thể xuất hiện dưới tên `frame_id`). |
# | `field.status.status` | `gps_status` | Trạng thái khóa sóng vệ tinh (ví dụ: 0 là STATUS_FIX). |
# | `field.status.service` | `gps_service` | Dịch vụ hệ thống vệ tinh sử dụng (ví dụ: 1 là GPS của Mỹ). |
# | `field.latitude` | `latitude` | Tọa độ vĩ độ địa lý (độ thập phân). |
# | `field.longitude` | `longitude` | Tọa độ kinh độ địa lý (độ thập phân). |
# | `field.altitude` | `gps_altitude` | Độ cao so với mực nước biển trung bình (MSL) hoặc Ellipsoid WGS-84 (mét). |
# | `field.position_covariance0` ... `8` | `gps_position_covariance_0` ... `8` | Các thành phần của ma trận hiệp biến $3 \times 3$ biểu thị sai số ước lượng vị trí ($m^2$). |
# | `field.position_covariance_type` | `gps_position_covariance_type` | Phân loại cách tính ma trận sai số hiệp biến (ví dụ: 1). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Định vị cục bộ tích hợp GPS (GPS-Fused Local Position & Odometry) - `mavros-global_position-local.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin. |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds). |
# | `field.header.frame_id` | `frame_id` | Hệ quy chiếu mốc cố định trên mặt đất (ví dụ: map). |
# | `field.child_frame_id` | `child_frame_id` | Hệ quy chiếu gắn trên thân máy bay (ví dụ: base_link). |
# | `field.pose.pose.position.x` | `gps_local_position_x` | Vị trí hiệu chỉnh GPS theo trục X (hướng Bắc/Nam - hệ NED) (mét). |
# | `field.pose.pose.position.y` | `gps_local_position_y` | Vị trí hiệu chỉnh GPS theo trục Y (hướng Đông/Tây - hệ NED) (mét). |
# | `field.pose.pose.position.z` | `gps_local_position_z` | Vị trí hiệu chỉnh GPS theo trục Z (cao độ thực tế) (mét). |
# | `field.pose.pose.orientation.x` | `gps_local_orientation_qx` | Thành phần X của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.pose.pose.orientation.y` | `gps_local_orientation_qy` | Thành phần Y của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.pose.pose.orientation.z` | `gps_local_orientation_qz` | Thành phần Z của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.pose.pose.orientation.w` | `gps_local_orientation_qw` | Thành phần W của tọa độ liên hợp ảo Quaternion (góc xoay 3D). |
# | `field.twist.twist.linear.x` | `gps_local_linear_velocity_x` | Vận tốc tuyến tính theo hướng Bắc/Nam (hệ NED) (m/s). |
# | `field.twist.twist.linear.y` | `gps_local_linear_velocity_y` | Vận tốc tuyến tính theo hướng Đông/Tây (hệ NED) (m/s). |
# | `field.twist.twist.linear.z` | `gps_local_linear_velocity_z` | Vận tốc tuyến tính theo hướng Lên/Xuống (hệ NED) (m/s). |
# | `field.twist.twist.angular.x` | `gps_local_angular_velocity_x` | Tốc độ quay quanh trục dọc (thường có giá trị 0.0 trong bộ lọc GPS cục bộ) (rad/s). |
# | `field.twist.twist.angular.y` | `gps_local_angular_velocity_y` | Tốc độ quay quanh trục ngang (thường có giá trị 0.0 trong bộ lọc GPS cục bộ) (rad/s). |
# | `field.twist.twist.angular.z` | `gps_local_angular_velocity_z` | Tốc độ quay quanh trục đứng (thường có giá trị 0.0 trong bộ lọc GPS cục bộ) (rad/s). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường độ cao tương đối so với điểm cất cánh (Relative Altitude Measurement) - `mavros-global_position-rel_alt.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.data` | `relative_altitude` | Độ cao tương đối của máy bay so với điểm cất cánh (mét). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường hướng bay theo la bàn (Compass Heading Measurement) - `mavros-global_position-compass_hdg.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.data` | `compass_heading` | Hướng chỉ của mũi máy bay theo cảm biến la bàn số (độ). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Giá trị thiết lập điều khiển hành trình mục tiêu (Target Position & Velocity Setpoints) - `mavros-setpoint_raw-local.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: base_link - có thể xuất hiện dưới tên `frame_id`). |
# | `field.coordinate_frame` | `coordinate_frame` | Hằng số quy định hệ tọa độ mục tiêu (ví dụ: 1 cho FRAME_LOCAL_NED). |
# | `field.type_mask` | `type_mask` | Mặt nạ bit cấu hình các trường dữ liệu được bỏ qua hoặc sử dụng khi điều khiển. |
# | `field.position.x` | `target_position_x` | Vị trí mục tiêu theo trục X (hệ NED) (mét). |
# | `field.position.y` | `target_position_y` | Vị trí mục tiêu theo trục Y (hệ NED) (mét). |
# | `field.position.z` | `target_position_z` | Vị trí mục tiêu theo trục Z (hệ NED) (mét). |
# | `field.velocity.x` | `target_velocity_x` | Vận tốc mục tiêu theo trục X (hệ NED) (m/s). |
# | `field.velocity.y` | `target_velocity_y` | Vận tốc mục tiêu theo trục Y (hệ NED) (m/s). |
# | `field.velocity.z` | `target_velocity_z` | Vận tốc mục tiêu theo trục Z (hệ NED) (m/s). |
# | `field.acceleration_or_force.x` | `target_acceleration_x` | Gia tốc mục tiêu theo trục X (hệ NED) ($m/s^2$ hoặc lực N). |
# | `field.acceleration_or_force.y` | `target_acceleration_y` | Gia tốc mục tiêu theo trục Y (hệ NED) ($m/s^2$ hoặc lực N). |
# | `field.acceleration_or_force.z` | `target_acceleration_z` | Gia tốc mục tiêu theo trục Z (hệ NED) ($m/s^2$ hoặc lực N). |
# | `field.yaw` | `target_yaw` | Góc hướng mũi máy bay mục tiêu (radians). |
# | `field.yaw_rate` | `target_yaw_rate` | Tốc độ quay của góc yaw mục tiêu (rad/s). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Định vị vệ tinh toàn cầu GPS thô - Bản tin Fix (Raw GPS Global Positioning - Fix) - `mavros-global_position-raw-fix.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: base_link - có thể xuất hiện dưới tên `frame_id`). |
# | `field.status.status` | `gps_status` | Trạng thái định vị của bộ thu GPS (ví dụ: 0 là định vị tiêu chuẩn). |
# | `field.status.service` | `gps_service` | Dịch vụ hệ thống vệ tinh sử dụng (ví dụ: 1 là hệ thống GPS). |
# | `field.latitude` | `latitude` | Tọa độ vĩ độ địa lý thực tế (độ thập phân). |
# | `field.longitude` | `longitude` | Tọa độ kinh độ địa lý thực tế (độ thập phân). |
# | `field.altitude` | `gps_altitude` | Độ cao so với mặt ellipsoid tham chiếu WGS84 (mét). |
# | `field.position_covariance0` ... `8` | `gps_position_covariance_0` ... `8` | Các thành phần của ma trận hiệp biến $3 \times 3$ biểu thị sai số ước lượng vị trí ($m^2$). |
# | `field.position_covariance_type` | `gps_position_covariance_type` | Phân loại cách xác định ma trận sai số hiệp biến (ví dụ: 1 là ước tính xấp xỉ). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường vận tốc từ cảm biến GPS thô (Raw GPS Velocity Measurement) - `mavros-global_position-raw-gps_vel.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: map - có thể xuất hiện dưới tên `frame_id`). |
# | `field.twist.linear.x` | `gps_raw_linear_velocity_x` | Vận tốc tuyến tính thô theo hướng Đông/Tây (hệ ENU) đo từ vệ tinh (m/s). |
# | `field.twist.linear.y` | `gps_raw_linear_velocity_y` | Vận tốc tuyến tính thô theo hướng Bắc/Nam (hệ ENU) đo từ vệ tinh (m/s). |
# | `field.twist.linear.z` | `gps_raw_linear_velocity_z` | Vận tốc tuyến tính thô theo chiều thẳng đứng (hướng Lên) đo từ vệ tinh (m/s). |
# | `field.twist.angular.x` | `gps_raw_angular_velocity_x` | Vận tốc góc thô đo từ vệ tinh (luôn bằng 0.0 do GPS thô không đo được góc quay) (rad/s). |
# | `field.twist.angular.y` | `gps_raw_angular_velocity_y` | Vận tốc góc thô đo từ vệ tinh (luôn bằng 0.0 do GPS thô không đo được góc quay) (rad/s). |
# | `field.twist.angular.z` | `gps_raw_angular_velocity_z` | Vận tốc góc thô đo từ vệ tinh (luôn bằng 0.0 do GPS thô không đo được góc quay) (rad/s). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường quán tính thực tế từ cảm biến IMU (IMU Inertial Measurement) - `mavros-imu-data.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: base_link). |
# | `field.orientation.x` | `imu_orientation_qx` | Thành phần X của Quaternion ước lượng tư thế từ IMU. |
# | `field.orientation.y` | `imu_orientation_qy` | Thành phần Y của Quaternion ước lượng tư thế từ IMU. |
# | `field.orientation.z` | `imu_orientation_qz` | Thành phần Z của Quaternion ước lượng tư thế từ IMU. |
# | `field.orientation.w` | `imu_orientation_qw` | Thành phần W của Quaternion ước lượng tư thế từ IMU. |
# | `field.orientation_covariance0` ... `8` | `imu_orientation_covariance_0` ... `8` | Các thành phần của ma trận hiệp biến $3 \times 3$ sai số tư thế ($rad^2$). |
# | `field.angular_velocity.x` | `imu_angular_velocity_x` | Tốc độ quay quanh trục dọc thân máy bay (Roll rate) từ Gyroscope (rad/s). |
# | `field.angular_velocity.y` | `imu_angular_velocity_y` | Tốc độ quay quanh trục ngang thân máy bay (Pitch rate) từ Gyroscope (rad/s). |
# | `field.angular_velocity.z` | `imu_angular_velocity_z` | Tốc độ quay quanh trục đứng thân máy bay (Yaw rate) từ Gyroscope (rad/s). |
# | `field.angular_velocity_covariance0` ... `8` | `imu_angular_velocity_covariance_0` ... `8` | Các thành phần ma trận hiệp biến $3 \times 3$ sai số tốc độ góc ($(rad/s)^2$). |
# | `field.linear_acceleration.x` | `imu_linear_acceleration_x` | Gia tốc tuyến tính thực tế trục dọc thân máy bay từ Accelerometer ($m/s^2$). |
# | `field.linear_acceleration.y` | `imu_linear_acceleration_y` | Gia tốc tuyến tính thực tế trục ngang thân máy bay từ Accelerometer ($m/s^2$). |
# | `field.linear_acceleration.z` | `imu_linear_acceleration_z` | Gia tốc tuyến tính thực tế trục đứng (chứa cả trọng lực) từ Accelerometer ($m/s^2$). |
# | `field.linear_acceleration_covariance0` ... `8` | `imu_linear_acceleration_covariance_0` ... `8` | Các thành phần ma trận hiệp biến $3 \times 3$ sai số gia tốc ($(m/s^2)^2$). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Ước tính hướng và vận tốc gió thực tế (Wind Speed & Direction Estimation) - `mavros-wind_estimation.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (thường để trống trong topic này, nhưng ngầm hiểu là hệ ENU). |
# | `field.twist.linear.x` | `estimated_wind_velocity_x` | Vận tốc gió ước tính theo hướng Đông/Tây (hệ ENU) (m/s). |
# | `field.twist.linear.y` | `estimated_wind_velocity_y` | Vận tốc gió ước tính theo hướng Bắc/Nam (hệ ENU) (m/s). |
# | `field.twist.linear.z` | `estimated_wind_velocity_z` | Vận tốc gió ước tính theo hướng thẳng đứng (hướng Lên) (m/s). |
# | `field.twist.angular.x` | `estimated_wind_angular_velocity_x` | Tốc độ quay của khối khí quanh trục dọc (thường mặc định bằng 0.0) (rad/s). |
# | `field.twist.angular.y` | `estimated_wind_angular_velocity_y` | Tốc độ quay của khối khí quanh trục ngang (thường mặc định bằng 0.0) (rad/s). |
# | `field.twist.angular.z` | `estimated_wind_angular_velocity_z` | Tốc độ quay của khối khí quanh trục đứng (thường mặc định bằng 0.0) (rad/s). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường quán tính thô từ cảm biến IMU (Raw IMU Inertial Measurement) - `mavros-imu-data_raw.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk đọc dữ liệu thô (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: base_link). |
# | `field.orientation.x` | `imu_raw_orientation_qx` | Thành phần X của Quaternion tư thế (luôn bằng 0.0 trong bản tin thô). |
# | `field.orientation.y` | `imu_raw_orientation_qy` | Thành phần Y của Quaternion tư thế (luôn bằng 0.0 trong bản tin thô). |
# | `field.orientation.z` | `imu_raw_orientation_qz` | Thành phần Z của Quaternion tư thế (luôn bằng 0.0 trong bản tin thô). |
# | `field.orientation.w` | `imu_raw_orientation_qw` | Thành phần W của Quaternion tư thế (luôn bằng 0.0 trong bản tin thô). |
# | `field.orientation_covariance0` ... `8` | `imu_raw_orientation_covariance_0` ... `8` | Ma trận hiệp biến tư thế (phần tử đầu tiên mặc định bằng -1.0 để báo dữ liệu tư thế không hợp lệ). |
# | `field.angular_velocity.x` | `imu_raw_angular_velocity_x` | Tốc độ quay thô quanh trục dọc thân máy bay (Roll rate) từ Gyroscope (rad/s). |
# | `field.angular_velocity.y` | `imu_raw_angular_velocity_y` | Tốc độ quay thô quanh trục ngang thân máy bay (Pitch rate) từ Gyroscope (rad/s). |
# | `field.angular_velocity.z` | `imu_raw_angular_velocity_z` | Tốc độ quay thô quanh trục đứng thân máy bay (Yaw rate) từ Gyroscope (rad/s). |
# | `field.angular_velocity_covariance0` ... `8` | `imu_raw_angular_velocity_covariance_0` ... `8` | Các thành phần ma trận hiệp biến $3 \times 3$ sai số tốc độ góc thô ($(rad/s)^2$). |
# | `field.linear_acceleration.x` | `imu_raw_linear_acceleration_x` | Gia tốc tuyến tính thô trục dọc thân máy bay từ Accelerometer ($m/s^2$). |
# | `field.linear_acceleration.y` | `imu_raw_linear_acceleration_y` | Gia tốc tuyến tính thô trục ngang thân máy bay từ Accelerometer ($m/s^2$). |
# | `field.linear_acceleration.z` | `imu_raw_linear_acceleration_z` | Gia tốc tuyến tính thô trục đứng (chứa cả trọng lực) từ Accelerometer ($m/s^2$). |
# | `field.linear_acceleration_covariance0` ... `8` | `imu_raw_linear_acceleration_covariance_0` ... `8` | Các thành phần ma trận hiệp biến $3 \times 3$ sai số gia tốc thô ($(m/s^2)^2$). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường từ trường thực tế từ cảm biến từ kế (Magnetometer / Magnetic Field Measurement) - `mavros-imu-mag.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: base_link). |
# | `field.magnetic_field.x` | `magnetic_field_x` | Từ trường đo dọc theo trục dọc thân máy bay (hướng tiến/lùi) (Tesla hoặc nT). |
# | `field.magnetic_field.y` | `magnetic_field_y` | Từ trường đo dọc theo trục ngang thân máy bay (hướng trái/phải) (Tesla hoặc nT). |
# | `field.magnetic_field.z` | `magnetic_field_z` | Từ trường đo dọc theo trục thẳng đứng của máy bay (hướng lên/xuống) (Tesla hoặc nT). |
# | `field.magnetic_field_covariance0` ... `8` | `magnetic_field_covariance_0` ... `8` | Các thành phần ma trận hiệp biến $3 \times 3$ sai số từ trường (phần tử đầu tiên bằng -1.0 báo hiệu sai số không xác định). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường áp suất khí quyển thực tế từ cảm biến áp kế (Barometer / Atmospheric Pressure Measurement) - `mavros-imu-atm_pressure.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: base_link). |
# | `field.fluid_pressure` | `fluid_pressure` | Áp suất khí quyển tuyệt đối đo được tại vị trí của UAV (Pascal - Pa). |
# | `field.variance` | `fluid_pressure_variance` | Phương sai (độ sai số bình phương) của phép đo áp suất ($Pa^2$). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đo lường nhiệt độ hoạt động của cụm IMU (IMU Temperature Measurement) - `mavros-imu-temperature.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (ví dụ: base_link). |
# | `field.temperature` | `imu_temperature` | Nhiệt độ đo được bên trong cụm IMU (°C). |
# | `field.variance` | `imu_temperature_variance` | Phương sai (độ sai số bình phương) của phép đo nhiệt độ ($^\circ C^2$). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Giám sát trạng thái nguồn điện và pin (Battery & Power Supply Status Monitoring) - `mavros-battery.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian hệ thống/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (thường để trống đối với dữ liệu pin). |
# | `field.voltage` | `battery_voltage` | Điện áp hiện tại của pin (Vôn - V). |
# | `field.current` | `battery_current` | Dòng điện tức thời đang tiêu thụ từ pin (Ampe - A). |
# | `field.charge` | `battery_charge` | Dung lượng điện tích hiện tại của pin (Ampe-giờ - Ah). |
# | `field.capacity` | `battery_capacity` | Dung lượng tối đa thực tế của pin khi sạc đầy (Ampe-giờ - Ah). |
# | `field.design_capacity` | `battery_design_capacity` | Dung lượng thiết kế ban đầu của pin theo nhà sản xuất (Ampe-giờ - Ah). |
# | `field.percentage` | `battery_percentage` | Tỷ lệ phần trăm pin còn lại (từ 0.0 đến 1.0, -1% báo lỗi/chưa cấu hình). |
# | `field.power_supply_status` | `power_supply_status` | Trạng thái hoạt động của nguồn cấp (ví dụ: 2 là đang tiêu thụ/xả pin). |
# | `field.power_supply_health` | `power_supply_health` | Tình trạng sức khỏe vật lý của pin (ví dụ: 0 là chưa xác định). |
# | `field.power_supply_technology` | `power_supply_technology` | Công nghệ hóa chất chế tạo pin (ví dụ: 0 là chưa xác định). |
# | `field.present` | `battery_present` | Trạng thái kết nối vật lý của pin vào hệ thống (1 là đang cắm). |
# | `field.location` | `battery_location` | Vị trí khay cắm pin trên UAV. |
# | `field.serial_number` | `battery_serial_number` | Số sê-ri của pin (nếu có). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Thông số hiển thị HUD điều khiển bay (Visual Flight Rules HUD Telemetry) - `mavros-vfr_hud.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian cảm biến/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (thường được bỏ trống đối với tệp này). |
# | `field.airspeed` | `airspeed` | Tốc độ đối không thực tế của máy bay (m/s). |
# | `field.groundspeed` | `groundspeed` | Tốc độ đối đất đo đạc qua GPS (m/s). |
# | `field.heading` | `hud_heading` | Hướng mũi máy bay đang chỉ theo la bàn hiển thị trên HUD (độ). |
# | `field.throttle` | `throttle` | Giá trị tay ga ga động cơ thực tế, chuẩn hóa từ 0.0 đến 1.0 (0% đến 100%). |
# | `field.altitude` | `hud_altitude` | Độ cao hiện tại của máy bay so với mực nước biển trung bình (MSL) hiển thị trên HUD (mét). |
# | `field.climb` | `climb_rate` | Tốc độ leo cao hoặc hạ độ cao tức thời (m/s). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Tín hiệu điều khiển cơ cấu chấp hành đầu ra (RC / Servo Output Signals) - `mavros-rc-out.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian hệ thống/Pixhawk xuất lệnh (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (thường được bỏ trống đối với tệp này). |
# | `field.channels0` | `rc_out_aileron` | Độ rộng xung PWM điều khiển cánh liệng (Aileron - Kênh 1) ($\mu s$). |
# | `field.channels1` | `rc_out_elevator` | Độ rộng xung PWM điều khiển cánh lái độ cao (Elevator - Kênh 2) ($\mu s$). |
# | `field.channels2` | `rc_out_throttle` | Độ rộng xung PWM điều khiển tốc độ quay động cơ (Throttle - Kênh 3) ($\mu s$). |
# | `field.channels3` | `rc_out_rudder` | Độ rộng xung PWM điều khiển cánh lái hướng (Rudder - Kênh 4) ($\mu s$). |
# | `field.channels4` | `rc_out_aux_5` | Độ rộng xung PWM điều khiển cánh tà/phụ trợ (Kênh 5) ($\mu s$). |
# | `field.channels5` | `rc_out_aux_6` | Độ rộng xung PWM điều khiển cánh tà/phụ trợ (Kênh 6) ($\mu s$). |
# | `field.channels6` | `rc_out_aux_7` | Độ rộng xung PWM điều khiển kênh phụ trợ/dự phòng (Kênh 7) ($\mu s$). |
# | `field.channels7` | `rc_out_aux_8` | Độ rộng xung PWM điều khiển kênh phụ trợ/chế độ bay (Kênh 8) ($\mu s$). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Tín hiệu điều khiển nhận từ tay cầm của phi công (RC Input Control Signals) - `mavros-rc-in.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian hệ thống tạo gói tin (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (thường để trống). |
# | `field.rssi` | `rc_input_rssi` | Chỉ số cường độ tín hiệu nhận được (Received Signal Strength Indicator), từ 0 đến 255. |
# | `field.channels0` | `rc_in_aileron` | Lệnh điều khiển cánh liệng (Aileron - Kênh 1) từ tay cầm phi công ($\mu s$). |
# | `field.channels1` | `rc_in_elevator` | Lệnh điều khiển cánh lái độ cao (Elevator - Kênh 2) từ tay cầm phi công ($\mu s$). |
# | `field.channels2` | `rc_in_throttle` | Lệnh điều khiển ga động cơ (Throttle - Kênh 3) từ tay cầm phi công ($\mu s$). |
# | `field.channels3` | `rc_in_rudder` | Lệnh điều khiển cánh lái hướng (Rudder - Kênh 4) từ tay cầm phi công ($\mu s$). |
# | `field.channels4` | `rc_in_aux_5` | Giá trị điều khiển kênh phụ trợ/chế độ bay (Kênh 5) ($\mu s$). |
# | `field.channels5` | `rc_in_aux_6` | Giá trị điều khiển kênh phụ trợ (Kênh 6) ($\mu s$). |
# | `field.channels6` | `rc_in_aux_7` | Giá trị điều khiển kênh phụ trợ (Kênh 7) ($\mu s$). |
# | `field.channels7` | `rc_in_aux_8` | Giá trị điều khiển kênh phụ trợ (Kênh 8) ($\mu s$). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Giá trị thiết lập điều khiển vị trí toàn cầu mục tiêu (Global Target Position & Velocity Setpoints) - `mavros-setpoint_raw-target_global.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian hệ thống tạo gói tin (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (thường là map). |
# | `field.coordinate_frame` | `coordinate_frame` | Mã tiêu chuẩn MAVLink cho hệ quy chiếu mục tiêu toàn cầu (ví dụ: giá trị 5 cho GPS toàn cầu). |
# | `field.type_mask` | `type_mask` | Mặt nạ bit cấu hình các trường dữ liệu được bỏ qua hoặc sử dụng khi điều khiển mục tiêu. |
# | `field.latitude` | `target_latitude` | Tọa độ vĩ độ mục tiêu (độ thập phân). |
# | `field.longitude` | `target_longitude` | Tọa độ kinh độ mục tiêu (độ thập phân). |
# | `field.altitude` | `target_altitude` | Độ cao mục tiêu so với mặt ellipsoid tham chiếu hoặc mực nước biển (mét). |
# | `field.velocity.x` | `target_velocity_x` | Vận tốc mục tiêu theo trục X (hướng Bắc/Nam - hệ NED) (m/s). |
# | `field.velocity.y` | `target_velocity_y` | Vận tốc mục tiêu theo trục Y (hướng Đông/Tây - hệ NED) (m/s). |
# | `field.velocity.z` | `target_velocity_z` | Vận tốc mục tiêu theo trục Z (hướng thẳng đứng) (m/s). |
# | `field.acceleration_or_force.x` | `target_acceleration_x` | Gia tốc mục tiêu theo trục X ($m/s^2$ hoặc lực N). |
# | `field.acceleration_or_force.y` | `target_acceleration_y` | Gia tốc mục tiêu theo trục Y ($m/s^2$ hoặc lực N). |
# | `field.acceleration_or_force.z` | `target_acceleration_z` | Gia tốc mục tiêu theo trục Z ($m/s^2$ hoặc lực N). |
# | `field.yaw` | `target_yaw` | Góc hướng mũi máy bay mục tiêu (radians). |
# | `field.yaw_rate` | `target_yaw_rate` | Tốc độ quay của góc yaw mục tiêu (rad/s). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Giám sát trạng thái kết nối và chế độ bay của UAV (UAV Connection & Flight Mode Status) - `mavros-state.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian hệ thống/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (thường được bỏ trống đối với dữ liệu trạng thái). |
# | `field.connected` | `is_connected` | Trạng thái kết nối giữa trạm mặt đất/máy tính nhúng với Pixhawk (1 là đã kết nối). |
# | `field.armed` | `is_armed` | Trạng thái kích hoạt động cơ (1 là đã kích hoạt/Armed). |
# | `field.guided` | `is_guided` | Trạng thái UAV đang bay ở chế độ nhận lệnh dẫn đường tự động (1 là True). |
# | `field.mode` | `flight_mode` | Chế độ bay hiện tại của UAV (ví dụ: GUIDED, MANUAL, AUTO...). |
# | `field.system_status` | `system_status` | Trạng thái hệ thống theo tiêu chuẩn MAVLink (ví dụ: 4 tương ứng với hằng số `MAV_STATE_ACTIVE` - hệ thống đang hoạt động bình thường). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Báo cáo chẩn đoán trạng thái phần cứng và hệ thống (UAV System & Hardware Diagnostics) - `diagnostics.csv`**
#
# Vì tệp dữ liệu này có cấu trúc rất đồ sộ và lặp lại theo dạng mảng phẳng (flattened array) trong ROS (lên tới 125 cột, bao gồm 5 cụm trạng thái từ `status0` đến `status4` và các cặp key-value từ `values0` đến `values25`), việc liệt kê thủ công từng cột sẽ rất dài.
#
# Do đó, bảng dưới đây định nghĩa **quy luật đặt tên cột tổng quát** (với `N` là chỉ số cụm trạng thái từ `0` đến `4`, và `M` là chỉ số cặp giá trị từ `0` đến `25`):
#
# ### Bảng đối chiếu tên cột dữ liệu tổng quát
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian hệ thống/Pixhawk tạo dữ liệu (nanoseconds). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (thường để trống). |
# | `field.statusN.level` | `diag_level_N` | Mức độ lỗi cụm N (0: OK, 1: Warning, 2: Error, 3: Stale). |
# | `field.statusN.name` | `diag_name_N` | Tên cụm chẩn đoán N (ví dụ: "mavros: GPS"). |
# | `field.statusN.message` | `diag_message_N` | Thông điệp mô tả trạng thái cụm N (ví dụ: "Sensor helth"). |
# | `field.statusN.hardware_id` | `diag_hardware_id_N` | Định danh phần cứng hoặc địa chỉ kết nối của cụm N. |
# | `field.statusN.valuesM.key` | `diag_N_val_key_M` | Nhãn (Key) của tham số thứ M trong cụm N (ví dụ: "3D magnetometer"). |
# | `field.statusN.valuesM.value`| `diag_N_val_value_M` | Giá trị thực tế của tham số thứ M trong cụm N (ví dụ: "Fail"). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Đồng bộ hóa mốc thời gian hệ thống (Time Synchronization & Reference) - `mavros-time_reference.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian hệ thống/Pixhawk tạo dữ liệu (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (thường được bỏ trống đối với dữ liệu thời gian). |
# | `field.time_ref` | `reference_time_ns` | Mốc thời gian tham chiếu gốc từ thiết bị nguồn (nanoseconds). |
# | `field.source` | `time_source` | Thiết bị cung cấp mốc thời gian tham chiếu (ví dụ: "fcu" - Flight Control Unit/Pixhawk). |

# %% [markdown]
# ### Tên chức năng / Tệp nguồn:
# **Giám sát luồng gói tin MAVLink thô (Raw MAVLink Packet Monitoring) - `mavros-mavlink-from.csv`**
#
# ### Bảng đối chiếu tên cột dữ liệu
#
# | Tên gốc trong ROS | Tên cột đề xuất (`snake_case`) | Ý nghĩa và lưu ý |
# | :--- | :--- | :--- |
# | `%time` | `recording_timestamp` | Thời gian hệ thống ghi nhận (nanoseconds). |
# | `field.header.seq` | `sequence_number` | Số thứ tự gói tin ROS (có thể xuất hiện dưới tên `seq`). |
# | `field.header.stamp` | `sensor_timestamp` | Thời gian hệ thống tạo gói tin ROS (nanoseconds - có thể xuất hiện dưới tên `stamp`). |
# | `field.header.frame_id` | `frame_id` | Hệ tọa độ tham chiếu chung (thường được bỏ trống đối với tệp này). |
# | `field.framing_status` | `framing_status` | Trạng thái khung của gói tin (ví dụ: 1 là OK/Hợp lệ). |
# | `field.magic` | `mavlink_magic_byte` | Byte ma thuật định dạng phiên bản MAVLink (ví dụ: 254/0xFE là MAVLink v1.0). |
# | `field.len` | `payload_length` | Độ dài của phần dữ liệu có ích (payload) trong gói tin (bytes). |
# | `field.incompat_flags` | `incompatibility_flags` | Các cờ không tương thích (chỉ có trong MAVLink v2.0, thường bằng 0). |
# | `field.compat_flags` | `compatibility_flags` | Các cờ tương thích (chỉ có trong MAVLink v2.0, thường bằng 0). |
# | `field.seq` | `mavlink_packet_seq` | Số thứ tự gói tin trong giao thức MAVLink (để phân biệt với `sequence_number` của ROS). |
# | `field.sysid` | `mavlink_sys_id` | Định danh hệ thống gửi gói tin (System ID, thường là 1 đối với UAV). |
# | `field.compid` | `mavlink_comp_id` | Định danh thành phần gửi gói tin (Component ID, thường là 1 đối với Autopilot). |
# | `field.msgid` | `mavlink_msg_id` | ID của loại bản tin MAVLink (ví dụ: 33 là GLOBAL_POSITION_INT, 32 là LOCAL_POSITION_NED). [2.1] |
# | `field.checksum` | `mavlink_checksum` | Mã kiểm tra sai số kiểm dư tuần hoàn (CRC-16 checksum) của gói tin. |
# | `field.payload640` ... `3` | `mavlink_payload_64_0` ... `3` | Các khối dữ liệu payload thô được phân tách dưới dạng mảng số nguyên không dấu 64-bit. |
